# %% [markdown]
# # <font color="red"> SCC5871/MAI5025</font>
# ## <span style="color:red">APRENDIZADO DE MÁQUINA</span>
# ## **Exemplo de Uso de LSTM**
#
# ### **REDES NEURAIS RECORRENTES**
#
#
# ### Profa. Roseli Ap. Francelin Romero
#
# **PROBLEMA**: SERIE TEMPORAL - Previsão de passageiros de uma Cia Aérea Internacional.
#
# Este é um problema em que, dados um ano e um mês, a tarefa é prever o número de passageiros (em unidades de 1.000) de companhias aéreas internacionais. Os dados variam de janeiro de 1949 a dezembro de 1960,  12 anos, com 144 observações.

# %% [markdown]
# Por default o Keras mantem um estado com um batch (stateful=True). Um batch é um no. de linhas do conjunto de dados usado para o treinamento. Entre uma camada e outra na LTSM o estado é desconsiderado (limpado) por default. Isto nos dá um controle mais fino entre os estados e podemos usar a função resetstates(). <\br>
#
# **LSTM PARA REGRESSÃO** A cam. LSTM espera uma matriz como entrada: [samples, time steps, features], onde?
#
# **Samples**: são as observações do dominio da aplicação, normalmente as linhas do dataset.</br>
# **Time steps**: são passos de tempo de separação de uma dada variavel para uma dada observação.</br>
# **Features**: são medidas separadas observadas em cada tempo da observação.
#
# Nesta série, os seguintes passos serão considerados:
#
# - Carregar o dataset do CSV file.
# - Transformar o dataset de modo a adequa-lo para o modelo LSTM, incluindo:
# - 1 - Transformar os dados para um problema de aprendizado supervisionado.
# - 2 - Transformar os dados para ser "stationary".
# - 3 - Transformar os dados para que fiquem no interv. [-1,1].
# - 4 - Ajusta o modelo da rede LSTM para o conj. de treinamento.
# - 5 - Avaliar o modelo LSTM estático no conjunto de teste.
# - 6 - Visualizar o desempenho da Previsão.

# %%
# LSTM for international airline passengers problem with regression framing
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# converte um array de valores numa matriz de dados 
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)
 
# as sementes ajudam a ter resultados reproduzíveis
from numpy.random import seed
seed(1)
from tensorflow.random import set_seed
set_seed(2)

# Carregar o dataset
dataframe = read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv', usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')

# %%
# normalizar o dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# Out:
# array([[0.01544401],
#        [0.02702703],
#        [0.05405405]], dtype=float32)

# %%
# dividir em conjuntos de train and test 
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
# reshape em X=t and Y=t+1
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

print('X(t)', 'Y(t+1)')
for i in range(len(trainX)):
  print(trainX[i], trainY[i])
# Out:
# X(t) Y(t+1)
# [0.01544401] 0.027027026
# [0.02702703] 0.05405405
# [0.05405405] 0.04826255
# [0.04826255] 0.032818526
# [0.03281853] 0.059845567
# [0.05984557] 0.08494207
# [0.08494207] 0.08494207
# [0.08494207] 0.06177607
# [0.06177607] 0.02895753
# [0.02895753] 0.0
# [0.] 0.027027026
# [0.02702703] 0.021235526
# [0.02123553] 0.042471036
# [0.04247104] 0.07142857
# [0.07142857] 0.059845567
# [0.05984557] 0.040540546
# [0.04054055] 0.08687258
# [0.08687258] 0.12741312
# [0.12741312] 0.12741312
# [0.12741312] 0.10424709
# [0.10424709] 0.055984557
# [0.05598456] 0.01930502
# [0.01930502] 0.06949806
# [0.06949806] 0.07915059
# [0.07915059] 0.08880308
# [0.08880308] 0.14285713
# [0.14285713] 0.11389962
# [0.11389962] 0.13127413
# [0.13127413] 0.14285713
# [0.14285713] 0.18339768
# [0.18339768] 0.18339768
# [0.18339768] 0.15444016
# [0.15444016] 0.11196911
# [0.11196911] 0.08108109
# [0.08108109] 0.1196911
# [0.1196911] 0.12934363
# [0.12934363] 0.14671814
# [0.14671814] 0.17181468
# [0.17181468] 0.14864865
# [0.14864865] 0.15250966
# [0.15250966] 0.22007722
# [0.22007722] 0.24324325
# [0.24324325] 0.26640925
# [0.26640925] 0.2027027
# [0.2027027] 0.16795367
# [0.16795367] 0.13127413
# [0.13127413] 0.17374519
# [0.17374519] 0.17760617
# [0.17760617] 0.17760617
# [0.17760617] 0.25482625
# [0.25482625] 0.25289574
# [0.25289574] 0.24131274
# [0.24131274] 0.26833975
# [0.26833975] 0.3088803
# [0.3088803] 0.32432434
# [0.32432434] 0.25675675
# [0.25675675] 0.20656371
# [0.20656371] 0.14671814
# [0.14671814] 0.18725869
# [0.18725869] 0.19305018
# [0.19305018] 0.16216215
# [0.16216215] 0.25289574
# [0.25289574] 0.23745173
# [0.23745173] 0.25096524
# [0.25096524] 0.3088803
# [0.3088803] 0.38223937
# [0.38223937] 0.36486486
# [0.36486486] 0.2992278
# [0.2992278] 0.24131274
# [0.24131274] 0.1911197
# [0.1911197] 0.24131274
# [0.24131274] 0.26640925
# [0.26640925] 0.24903473
# [0.24903473] 0.31467178
# [0.31467178] 0.3185328
# [0.3185328] 0.32046333
# [0.32046333] 0.4073359
# [0.4073359] 0.5019305
# [0.5019305] 0.46911195
# [0.46911195] 0.40154442
# [0.40154442] 0.32818535
# [0.32818535] 0.25675675
# [0.25675675] 0.3359073
# [0.3359073] 0.34749034
# [0.34749034] 0.33397684
# [0.33397684] 0.41119692
# [0.41119692] 0.4034749
# [0.4034749] 0.4131274
# [0.4131274] 0.52123547
# [0.52123547] 0.5965251
# [0.5965251] 0.58108103
# [0.58108103] 0.484556
# [0.484556] 0.3899614
# [0.3899614] 0.3223938

# %%
# reshape entrada na forma [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
trainX[0:3]
# Out:
# array([[[0.01544401]],
#
#        [[0.02702703]],
#
#        [[0.05405405]]], dtype=float32)

# %%
# criando and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
model.summary()
# Out:
# Epoch 1/100
# 94/94 - 1s - loss: 0.0429 - 1s/epoch - 15ms/step
# Epoch 2/100
# 94/94 - 0s - loss: 0.0209 - 114ms/epoch - 1ms/step
# Epoch 3/100
# 94/94 - 0s - loss: 0.0154 - 117ms/epoch - 1ms/step
# Epoch 4/100
# 94/94 - 0s - loss: 0.0138 - 95ms/epoch - 1ms/step
# Epoch 5/100
# 94/94 - 0s - loss: 0.0129 - 98ms/epoch - 1ms/step
# Epoch 6/100
# 94/94 - 0s - loss: 0.0119 - 95ms/epoch - 1ms/step
# Epoch 7/100
# 94/94 - 0s - loss: 0.0111 - 131ms/epoch - 1ms/step
# Epoch 8/100
# 94/94 - 0s - loss: 0.0100 - 97ms/epoch - 1ms/step
# Epoch 9/100
# 94/94 - 0s - loss: 0.0091 - 98ms/epoch - 1ms/step
# Epoch 10/100
# 94/94 - 0s - loss: 0.0082 - 101ms/epoch - 1ms/step
# Epoch 11/100
# 94/94 - 0s - loss: 0.0073 - 99ms/epoch - 1ms/step
# Epoch 12/100
# 94/94 - 0s - loss: 0.0064 - 96ms/epoch - 1ms/step
# Epoch 13/100
# 94/94 - 0s - loss: 0.0056 - 95ms/epoch - 1ms/step
# Epoch 14/100
# 94/94 - 0s - loss: 0.0049 - 94ms/epoch - 995us/step
# Epoch 15/100
# 94/94 - 0s - loss: 0.0043 - 94ms/epoch - 996us/step
# Epoch 16/100
# 94/94 - 0s - loss: 0.0037 - 93ms/epoch - 991us/step
# Epoch 17/100
# 94/94 - 0s - loss: 0.0033 - 94ms/epoch - 996us/step
# Epoch 18/100
# 94/94 - 0s - loss: 0.0029 - 91ms/epoch - 973us/step
# Epoch 19/100
# 94/94 - 0s - loss: 0.0027 - 92ms/epoch - 978us/step
# Epoch 20/100
# 94/94 - 0s - loss: 0.0024 - 92ms/epoch - 979us/step
# Epoch 21/100
# 94/94 - 0s - loss: 0.0023 - 90ms/epoch - 961us/step
# Epoch 22/100
# 94/94 - 0s - loss: 0.0022 - 92ms/epoch - 980us/step
# Epoch 23/100
# 94/94 - 0s - loss: 0.0022 - 90ms/epoch - 960us/step
# Epoch 24/100
# 94/94 - 0s - loss: 0.0021 - 101ms/epoch - 1ms/step
# Epoch 25/100
# 94/94 - 0s - loss: 0.0021 - 104ms/epoch - 1ms/step
# Epoch 26/100
# 94/94 - 0s - loss: 0.0020 - 90ms/epoch - 954us/step
# Epoch 27/100
# 94/94 - 0s - loss: 0.0021 - 94ms/epoch - 1000us/step
# Epoch 28/100
# 94/94 - 0s - loss: 0.0021 - 91ms/epoch - 971us/step
# Epoch 29/100
# 94/94 - 0s - loss: 0.0020 - 90ms/epoch - 961us/step
# Epoch 30/100
# 94/94 - 0s - loss: 0.0021 - 92ms/epoch - 974us/step
# Epoch 31/100
# 94/94 - 0s - loss: 0.0020 - 91ms/epoch - 971us/step
# Epoch 32/100
# 94/94 - 0s - loss: 0.0021 - 92ms/epoch - 980us/step
# Epoch 33/100
# 94/94 - 0s - loss: 0.0021 - 92ms/epoch - 983us/step
# Epoch 34/100
# 94/94 - 0s - loss: 0.0020 - 92ms/epoch - 974us/step
# Epoch 35/100
# 94/94 - 0s - loss: 0.0021 - 92ms/epoch - 979us/step
# Epoch 36/100
# 94/94 - 0s - loss: 0.0020 - 93ms/epoch - 987us/step
# Epoch 37/100
# 94/94 - 0s - loss: 0.0021 - 116ms/epoch - 1ms/step
# Epoch 38/100
# 94/94 - 0s - loss: 0.0021 - 96ms/epoch - 1ms/step
# Epoch 39/100
# 94/94 - 0s - loss: 0.0020 - 91ms/epoch - 971us/step
# Epoch 40/100
# 94/94 - 0s - loss: 0.0021 - 92ms/epoch - 984us/step
# Epoch 41/100
# 94/94 - 0s - loss: 0.0021 - 91ms/epoch - 964us/step
# Epoch 42/100
# 94/94 - 0s - loss: 0.0020 - 91ms/epoch - 968us/step
# Epoch 43/100
# 94/94 - 0s - loss: 0.0020 - 92ms/epoch - 980us/step
# Epoch 44/100
# 94/94 - 0s - loss: 0.0021 - 93ms/epoch - 991us/step
# Epoch 45/100
# 94/94 - 0s - loss: 0.0020 - 93ms/epoch - 990us/step
# Epoch 46/100
# 94/94 - 0s - loss: 0.0021 - 93ms/epoch - 984us/step
# Epoch 47/100
# 94/94 - 0s - loss: 0.0020 - 93ms/epoch - 984us/step
# Epoch 48/100
# 94/94 - 0s - loss: 0.0020 - 92ms/epoch - 974us/step
# Epoch 49/100
# 94/94 - 0s - loss: 0.0021 - 92ms/epoch - 974us/step
# Epoch 50/100
# 94/94 - 0s - loss: 0.0020 - 92ms/epoch - 979us/step
# Epoch 51/100
# 94/94 - 0s - loss: 0.0021 - 90ms/epoch - 960us/step
# Epoch 52/100
# 94/94 - 0s - loss: 0.0020 - 93ms/epoch - 992us/step
# Epoch 53/100
# 94/94 - 0s - loss: 0.0021 - 92ms/epoch - 980us/step
# Epoch 54/100
# 94/94 - 0s - loss: 0.0021 - 93ms/epoch - 984us/step
# Epoch 55/100
# 94/94 - 0s - loss: 0.0020 - 92ms/epoch - 974us/step
# Epoch 56/100
# 94/94 - 0s - loss: 0.0021 - 90ms/epoch - 958us/step
# Epoch 57/100
# 94/94 - 0s - loss: 0.0021 - 92ms/epoch - 976us/step
# Epoch 58/100
# 94/94 - 0s - loss: 0.0020 - 91ms/epoch - 963us/step
# Epoch 59/100
# 94/94 - 0s - loss: 0.0021 - 93ms/epoch - 984us/step
# Epoch 60/100
# 94/94 - 0s - loss: 0.0021 - 92ms/epoch - 974us/step
# Epoch 61/100
# 94/94 - 0s - loss: 0.0020 - 108ms/epoch - 1ms/step
# Epoch 62/100
# 94/94 - 0s - loss: 0.0021 - 95ms/epoch - 1ms/step
# Epoch 63/100
# 94/94 - 0s - loss: 0.0021 - 94ms/epoch - 995us/step
# Epoch 64/100
# 94/94 - 0s - loss: 0.0021 - 96ms/epoch - 1ms/step
# Epoch 65/100
# 94/94 - 0s - loss: 0.0020 - 100ms/epoch - 1ms/step
# Epoch 66/100
# 94/94 - 0s - loss: 0.0020 - 98ms/epoch - 1ms/step
# Epoch 67/100
# 94/94 - 0s - loss: 0.0022 - 95ms/epoch - 1ms/step
# Epoch 68/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 69/100
# 94/94 - 0s - loss: 0.0021 - 96ms/epoch - 1ms/step
# Epoch 70/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 71/100
# 94/94 - 0s - loss: 0.0021 - 92ms/epoch - 980us/step
# Epoch 72/100
# 94/94 - 0s - loss: 0.0020 - 91ms/epoch - 973us/step
# Epoch 73/100
# 94/94 - 0s - loss: 0.0020 - 125ms/epoch - 1ms/step
# Epoch 74/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 995us/step
# Epoch 75/100
# 94/94 - 0s - loss: 0.0020 - 95ms/epoch - 1ms/step
# Epoch 76/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 995us/step
# Epoch 77/100
# 94/94 - 0s - loss: 0.0020 - 93ms/epoch - 984us/step
# Epoch 78/100
# 94/94 - 0s - loss: 0.0020 - 96ms/epoch - 1ms/step
# Epoch 79/100
# 94/94 - 0s - loss: 0.0020 - 96ms/epoch - 1ms/step
# Epoch 80/100
# 94/94 - 0s - loss: 0.0020 - 95ms/epoch - 1ms/step
# Epoch 81/100
# 94/94 - 0s - loss: 0.0020 - 93ms/epoch - 991us/step
# Epoch 82/100
# 94/94 - 0s - loss: 0.0022 - 92ms/epoch - 974us/step
# Epoch 83/100
# 94/94 - 0s - loss: 0.0020 - 93ms/epoch - 984us/step
# Epoch 84/100
# 94/94 - 0s - loss: 0.0020 - 110ms/epoch - 1ms/step
# Epoch 85/100
# 94/94 - 0s - loss: 0.0021 - 97ms/epoch - 1ms/step
# Epoch 86/100
# 94/94 - 0s - loss: 0.0021 - 95ms/epoch - 1ms/step
# Epoch 87/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 88/100
# 94/94 - 0s - loss: 0.0021 - 95ms/epoch - 1ms/step
# Epoch 89/100
# 94/94 - 0s - loss: 0.0020 - 96ms/epoch - 1ms/step
# Epoch 90/100
# 94/94 - 0s - loss: 0.0020 - 98ms/epoch - 1ms/step
# Epoch 91/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 995us/step
# Epoch 92/100
# 94/94 - 0s - loss: 0.0020 - 91ms/epoch - 969us/step
# Epoch 93/100
# 94/94 - 0s - loss: 0.0020 - 92ms/epoch - 981us/step
# Epoch 94/100
# 94/94 - 0s - loss: 0.0020 - 93ms/epoch - 992us/step
# Epoch 95/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 995us/step
# Epoch 96/100
# 94/94 - 0s - loss: 0.0020 - 96ms/epoch - 1ms/step
# Epoch 97/100
# 94/94 - 0s - loss: 0.0020 - 91ms/epoch - 971us/step
# Epoch 98/100
# 94/94 - 0s - loss: 0.0020 - 93ms/epoch - 984us/step
# Epoch 99/100
# 94/94 - 0s - loss: 0.0020 - 92ms/epoch - 974us/step
# Epoch 100/100
# 94/94 - 0s - loss: 0.0020 - 92ms/epoch - 982us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 4)                 96
#
#  dense (Dense)               (None, 1)                 5
#
# =================================================================
# Total params: 101
# Trainable params: 101
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fazer as predicoes
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# Out:
# 3/3 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step

# %%
# inverter antes as predicoes
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calcular o RMSE error root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 23.70 RMSE
# Test Score: 46.76 RMSE

# %%
trainY.shape
# Out:
# (1, 94)

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

# %% [markdown]
# Vamos plotar o dataset original em azul, as predicoes para o conj. de treinamento em verde, e as predicoes dos dados de test em vermelho.

# %%
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset), color="blue")
plt.plot(trainPredictPlot, color="green")
plt.plot(testPredictPlot, color="red")
plt.show()

# %% [markdown]
# Podemos ver que o modelo tem um erro médio de cerca de 23 passageiros (em milhares) no conjunto de dados de treinamento e cerca de 50 passageiros (em milhares) no conjunto de dados de teste. Não tão ruim.

# %% [markdown]
# ####**LSTM for Regression Using the Window Method**

# %% [markdown]
# Também podemos formular o problema de forma que várias timesteps recentes possam ser usadas para fazer a previsão para o próximo timestep.
#
# Isso é chamado de **janela**, e o tamanho da janela é um parâmetro que pode ser ajustado para cada problema.
#
# Por exemplo, dado o tempo atual (t) que queremos prever o valor no próximo tempo na sequência (t + 1), podemos usar o tempo atual (t), bem como os dois tempos anteriores (t-1 e t-2) como variáveis ​​de entrada.
#
# Quando formulado como um problema de regressão, as variáveis ​​de entrada são t-2, t-1, t e a variável de saída é t + 1.
#
# A função **create_dataset()** criada nos permite allows criar esta formulação aumentando a var. **look_back** de 1 para 3.
#
# Exemplo:</br>
# X1	X2	X3	Y </br>
# 112	118	132	129 </br>
# 118	132	129	121 </br>
# 132	129	121	135 </br>
# 129	121	135	148 </br>
# 121	135	148	148 </br>

# %%
# reshape em X=t and Y=t+1
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
new_data=pd.DataFrame()

# %%
# reshape as entradas na forma [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
# cria e aplica a rede LSTM 
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# fazer as predicoes
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# inverter as predicoes
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calcular o RMSE - root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# shift prediçoes de treinamento para fazer o plot
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift prediçoes de teste para fazer o plot
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot original and predicoes
plt.plot(scaler.inverse_transform(dataset), color = "blue")
plt.plot(trainPredictPlot, color="green")
plt.plot(testPredictPlot, color="red")
plt.show()
# Out:
# Epoch 1/100
# 92/92 - 4s - loss: 0.0470 - 4s/epoch - 43ms/step
# Epoch 2/100
# 92/92 - 0s - loss: 0.0172 - 223ms/epoch - 2ms/step
# Epoch 3/100
# 92/92 - 0s - loss: 0.0125 - 212ms/epoch - 2ms/step
# Epoch 4/100
# 92/92 - 0s - loss: 0.0108 - 208ms/epoch - 2ms/step
# Epoch 5/100
# 92/92 - 0s - loss: 0.0095 - 205ms/epoch - 2ms/step
# Epoch 6/100
# 92/92 - 0s - loss: 0.0082 - 290ms/epoch - 3ms/step
# Epoch 7/100
# 92/92 - 0s - loss: 0.0071 - 316ms/epoch - 3ms/step
# Epoch 8/100
# 92/92 - 0s - loss: 0.0062 - 254ms/epoch - 3ms/step
# Epoch 9/100
# 92/92 - 0s - loss: 0.0055 - 348ms/epoch - 4ms/step
# Epoch 10/100
# 92/92 - 0s - loss: 0.0049 - 220ms/epoch - 2ms/step
# Epoch 11/100
# 92/92 - 0s - loss: 0.0045 - 249ms/epoch - 3ms/step
# Epoch 12/100
# 92/92 - 0s - loss: 0.0043 - 229ms/epoch - 2ms/step
# Epoch 13/100
# 92/92 - 0s - loss: 0.0040 - 286ms/epoch - 3ms/step
# Epoch 14/100
# 92/92 - 0s - loss: 0.0039 - 338ms/epoch - 4ms/step
# Epoch 15/100
# 92/92 - 0s - loss: 0.0038 - 284ms/epoch - 3ms/step
# Epoch 16/100
# 92/92 - 0s - loss: 0.0037 - 308ms/epoch - 3ms/step
# Epoch 17/100
# 92/92 - 0s - loss: 0.0037 - 253ms/epoch - 3ms/step
# Epoch 18/100
# 92/92 - 0s - loss: 0.0037 - 208ms/epoch - 2ms/step
# Epoch 19/100
# 92/92 - 0s - loss: 0.0037 - 196ms/epoch - 2ms/step
# Epoch 20/100
# 92/92 - 0s - loss: 0.0035 - 346ms/epoch - 4ms/step
# Epoch 21/100
# 92/92 - 0s - loss: 0.0036 - 251ms/epoch - 3ms/step
# Epoch 22/100
# 92/92 - 0s - loss: 0.0035 - 211ms/epoch - 2ms/step
# Epoch 23/100
# 92/92 - 0s - loss: 0.0035 - 237ms/epoch - 3ms/step
# Epoch 24/100
# 92/92 - 0s - loss: 0.0034 - 238ms/epoch - 3ms/step
# Epoch 25/100
# 92/92 - 0s - loss: 0.0034 - 269ms/epoch - 3ms/step
# Epoch 26/100
# 92/92 - 0s - loss: 0.0033 - 247ms/epoch - 3ms/step
# Epoch 27/100
# 92/92 - 0s - loss: 0.0034 - 137ms/epoch - 1ms/step
# Epoch 28/100
# 92/92 - 0s - loss: 0.0033 - 139ms/epoch - 2ms/step
# Epoch 29/100
# 92/92 - 0s - loss: 0.0033 - 155ms/epoch - 2ms/step
# Epoch 30/100
# 92/92 - 0s - loss: 0.0034 - 142ms/epoch - 2ms/step
# Epoch 31/100
# 92/92 - 0s - loss: 0.0032 - 144ms/epoch - 2ms/step
# Epoch 32/100
# 92/92 - 0s - loss: 0.0032 - 142ms/epoch - 2ms/step
# Epoch 33/100
# 92/92 - 0s - loss: 0.0032 - 139ms/epoch - 2ms/step
# Epoch 34/100
# 92/92 - 0s - loss: 0.0031 - 142ms/epoch - 2ms/step
# Epoch 35/100
# 92/92 - 0s - loss: 0.0031 - 143ms/epoch - 2ms/step
# Epoch 36/100
# 92/92 - 0s - loss: 0.0031 - 145ms/epoch - 2ms/step
# Epoch 37/100
# 92/92 - 0s - loss: 0.0031 - 139ms/epoch - 2ms/step
# Epoch 38/100
# 92/92 - 0s - loss: 0.0030 - 147ms/epoch - 2ms/step
# Epoch 39/100
# 92/92 - 0s - loss: 0.0030 - 145ms/epoch - 2ms/step
# Epoch 40/100
# 92/92 - 0s - loss: 0.0029 - 134ms/epoch - 1ms/step
# Epoch 41/100
# 92/92 - 0s - loss: 0.0030 - 145ms/epoch - 2ms/step
# Epoch 42/100
# 92/92 - 0s - loss: 0.0029 - 136ms/epoch - 1ms/step
# Epoch 43/100
# 92/92 - 0s - loss: 0.0028 - 154ms/epoch - 2ms/step
# Epoch 44/100
# 92/92 - 0s - loss: 0.0029 - 135ms/epoch - 1ms/step
# Epoch 45/100
# 92/92 - 0s - loss: 0.0029 - 145ms/epoch - 2ms/step
# Epoch 46/100
# 92/92 - 0s - loss: 0.0028 - 137ms/epoch - 1ms/step
# Epoch 47/100
# 92/92 - 0s - loss: 0.0028 - 142ms/epoch - 2ms/step
# Epoch 48/100
# 92/92 - 0s - loss: 0.0028 - 141ms/epoch - 2ms/step
# Epoch 49/100
# 92/92 - 0s - loss: 0.0027 - 143ms/epoch - 2ms/step
# Epoch 50/100
# 92/92 - 0s - loss: 0.0027 - 150ms/epoch - 2ms/step
# Epoch 51/100
# 92/92 - 0s - loss: 0.0028 - 137ms/epoch - 1ms/step
# Epoch 52/100
# 92/92 - 0s - loss: 0.0026 - 139ms/epoch - 2ms/step
# Epoch 53/100
# 92/92 - 0s - loss: 0.0027 - 143ms/epoch - 2ms/step
# Epoch 54/100
# 92/92 - 0s - loss: 0.0027 - 137ms/epoch - 1ms/step
# Epoch 55/100
# 92/92 - 0s - loss: 0.0025 - 146ms/epoch - 2ms/step
# Epoch 56/100
# 92/92 - 0s - loss: 0.0026 - 140ms/epoch - 2ms/step
# Epoch 57/100
# 92/92 - 0s - loss: 0.0026 - 152ms/epoch - 2ms/step
# Epoch 58/100
# 92/92 - 0s - loss: 0.0026 - 133ms/epoch - 1ms/step
# Epoch 59/100
# 92/92 - 0s - loss: 0.0025 - 141ms/epoch - 2ms/step
# Epoch 60/100
# 92/92 - 0s - loss: 0.0025 - 136ms/epoch - 1ms/step
# Epoch 61/100
# 92/92 - 0s - loss: 0.0026 - 146ms/epoch - 2ms/step
# Epoch 62/100
# 92/92 - 0s - loss: 0.0025 - 137ms/epoch - 1ms/step
# Epoch 63/100
# 92/92 - 0s - loss: 0.0024 - 143ms/epoch - 2ms/step
# Epoch 64/100
# 92/92 - 0s - loss: 0.0024 - 147ms/epoch - 2ms/step
# Epoch 65/100
# 92/92 - 0s - loss: 0.0025 - 140ms/epoch - 2ms/step
# Epoch 66/100
# 92/92 - 0s - loss: 0.0024 - 134ms/epoch - 1ms/step
# Epoch 67/100
# 92/92 - 0s - loss: 0.0022 - 138ms/epoch - 2ms/step
# Epoch 68/100
# 92/92 - 0s - loss: 0.0023 - 135ms/epoch - 1ms/step
# Epoch 69/100
# 92/92 - 0s - loss: 0.0023 - 138ms/epoch - 2ms/step
# Epoch 70/100
# 92/92 - 0s - loss: 0.0023 - 139ms/epoch - 2ms/step
# Epoch 71/100
# 92/92 - 0s - loss: 0.0023 - 151ms/epoch - 2ms/step
# Epoch 72/100
# 92/92 - 0s - loss: 0.0023 - 135ms/epoch - 1ms/step
# Epoch 73/100
# 92/92 - 0s - loss: 0.0023 - 141ms/epoch - 2ms/step
# Epoch 74/100
# 92/92 - 0s - loss: 0.0024 - 142ms/epoch - 2ms/step
# Epoch 75/100
# 92/92 - 0s - loss: 0.0022 - 140ms/epoch - 2ms/step
# Epoch 76/100
# 92/92 - 0s - loss: 0.0022 - 137ms/epoch - 1ms/step
# Epoch 77/100
# 92/92 - 0s - loss: 0.0023 - 141ms/epoch - 2ms/step
# Epoch 78/100
# 92/92 - 0s - loss: 0.0022 - 157ms/epoch - 2ms/step
# Epoch 79/100
# 92/92 - 0s - loss: 0.0022 - 144ms/epoch - 2ms/step
# Epoch 80/100
# 92/92 - 0s - loss: 0.0023 - 137ms/epoch - 1ms/step
# Epoch 81/100
# 92/92 - 0s - loss: 0.0023 - 142ms/epoch - 2ms/step
# Epoch 82/100
# 92/92 - 0s - loss: 0.0023 - 139ms/epoch - 2ms/step
# Epoch 83/100
# 92/92 - 0s - loss: 0.0022 - 144ms/epoch - 2ms/step
# Epoch 84/100
# 92/92 - 0s - loss: 0.0022 - 139ms/epoch - 2ms/step
# Epoch 85/100
# 92/92 - 0s - loss: 0.0021 - 154ms/epoch - 2ms/step
# Epoch 86/100
# 92/92 - 0s - loss: 0.0021 - 147ms/epoch - 2ms/step
# Epoch 87/100
# 92/92 - 0s - loss: 0.0022 - 139ms/epoch - 2ms/step
# Epoch 88/100
# 92/92 - 0s - loss: 0.0021 - 155ms/epoch - 2ms/step
# Epoch 89/100
# 92/92 - 0s - loss: 0.0021 - 131ms/epoch - 1ms/step
# Epoch 90/100
# 92/92 - 0s - loss: 0.0021 - 139ms/epoch - 2ms/step
# Epoch 91/100
# 92/92 - 0s - loss: 0.0022 - 139ms/epoch - 2ms/step
# Epoch 92/100
# 92/92 - 0s - loss: 0.0022 - 151ms/epoch - 2ms/step
# Epoch 93/100
# 92/92 - 0s - loss: 0.0022 - 157ms/epoch - 2ms/step
# Epoch 94/100
# 92/92 - 0s - loss: 0.0021 - 140ms/epoch - 2ms/step
# Epoch 95/100
# 92/92 - 0s - loss: 0.0022 - 141ms/epoch - 2ms/step
# Epoch 96/100
# 92/92 - 0s - loss: 0.0021 - 141ms/epoch - 2ms/step
# Epoch 97/100
# 92/92 - 0s - loss: 0.0021 - 146ms/epoch - 2ms/step
# Epoch 98/100
# 92/92 - 0s - loss: 0.0020 - 150ms/epoch - 2ms/step
# Epoch 99/100
# 92/92 - 0s - loss: 0.0021 - 148ms/epoch - 2ms/step
# Epoch 100/100
# 92/92 - 0s - loss: 0.0020 - 142ms/epoch - 2ms/step
# 3/3 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# Train Score: 22.98 RMSE
# Test Score: 57.42 RMSE

# %% [markdown]
# Podemos ver que o erro no conjunto de teste aumentou ligeiramente em relação ao da seção anterior. O tamanho da janela e a arquitetura da rede não foram ajustados: esta é apenas uma demonstração de como enjanelar um problema de previsão.

# %% [markdown]
# **LSTM com Memory entre os  Batches** </br>
#
# Normalmente, o estado dentro da rede é redefinido após cada batch (lote) de treinamento ao ajustar o modelo,
# bem como cada chamada para model.predict () ou
#  model.evaluate (). </br>
#
# Podemos obter um controle mais preciso sobre quando o estado interno da rede LSTM é desconsiderado,
# tornando a camada LSTM “com estado”. </br>
# Isso significa que ele pode criar um estado ao longo de toda a sequência de treinamento e
# até mesmo manter esse estado, se necessário, para fazer previsões. </br>
# **Por exemplo:**
# for i in range(100): </br>
# > model.fit(trainX, trainY, epochs=1, batch_size=batch_size, verbose=2, shuffle=False) </br>
# >	model.reset_states() </br>

# %%
## LSTM para o problema para passageiros em Cia Aerea Intern. com Memoria
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

 
# separar em conjuntos de train and test 
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# reshape em X=t and Y=t+1 agora com 3 timesteps anteriores
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape entrada na forma [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))
# criar e aplicar a rede LSTM 
batch_size = 1
model = Sequential()
model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
for i in range(100):
	model.fit(trainX, trainY, epochs=1, batch_size=batch_size, verbose=2, shuffle=False)
	model.reset_states()
# fazer as predicoes
trainPredict = model.predict(trainX, batch_size=batch_size)
model.reset_states()
testPredict = model.predict(testX, batch_size=batch_size)
# inverter as predicoes
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calcular o RMSE - root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# shift predicoes de treinamento para plotar
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift predicoes de teste para plotar
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot original e predicoes
plt.plot(scaler.inverse_transform(dataset), color="blue")
plt.plot(trainPredictPlot, color="green")
plt.plot(testPredictPlot, color="red")
plt.show()
# Out:
# 92/92 - 2s - loss: 0.0147 - 2s/epoch - 24ms/step
# 92/92 - 0s - loss: 0.0246 - 169ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0148 - 166ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0116 - 169ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0094 - 179ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0079 - 160ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0070 - 163ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0063 - 160ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0060 - 162ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0057 - 171ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0055 - 157ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0054 - 156ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0053 - 160ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0052 - 164ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0051 - 164ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0050 - 169ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0049 - 166ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0048 - 162ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0048 - 177ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0047 - 169ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0046 - 159ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0045 - 160ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0044 - 179ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0043 - 167ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0042 - 164ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0042 - 162ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0041 - 186ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0040 - 162ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0039 - 163ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0038 - 167ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0038 - 184ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0037 - 167ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0036 - 168ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0036 - 175ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0035 - 161ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0035 - 165ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0034 - 166ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0034 - 177ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0034 - 168ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0033 - 171ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0033 - 172ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0032 - 196ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0032 - 163ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0031 - 158ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0031 - 164ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0030 - 163ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0030 - 159ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0030 - 166ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0029 - 174ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0029 - 163ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0028 - 163ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0028 - 171ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0027 - 159ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0027 - 167ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0027 - 165ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0026 - 175ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0026 - 173ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0025 - 171ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0025 - 167ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0025 - 171ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0024 - 160ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0024 - 165ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0024 - 175ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0023 - 209ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0023 - 182ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0023 - 180ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0022 - 179ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0022 - 168ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0022 - 167ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0021 - 189ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0021 - 193ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0021 - 169ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0021 - 176ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0020 - 169ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0020 - 161ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0020 - 168ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0020 - 180ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0019 - 170ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0019 - 172ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0019 - 197ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0019 - 179ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0019 - 186ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0019 - 172ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0019 - 178ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0018 - 166ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0018 - 159ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0018 - 161ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0018 - 167ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0018 - 162ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0018 - 167ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0018 - 167ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0018 - 177ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0018 - 174ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0018 - 161ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0018 - 163ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0018 - 169ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0018 - 165ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0017 - 160ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0017 - 164ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0017 - 174ms/epoch - 2ms/step
# 92/92 [==============================] - 1s 2ms/step
# 44/44 [==============================] - 0s 2ms/step
# Train Score: 21.49 RMSE
# Test Score: 53.10 RMSE
